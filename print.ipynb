# %%
import matplotlib.pyplot as plt
import numpy as np
from readData import read_hit_rates

# %%
PATH = "./output.txt"

x = np.array([300,400,500,600])
lru = read_hit_rates(PATH, "LRU")
# plt.plot(x, da, label='das-lru')
# plt.plot(x, my, label='my_model-lru')
# plt.ylabel('hits')
# plt.legend()
# plt.show()
lru
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> PATH = "./output.txt"
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> x = np.array([300,400,500,600])
# ----> <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> lru = read_hit_rates(PATH, "LRU")
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> # plt.plot(x, da, label='das-lru')
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> # plt.plot(x, my, label='my_model-lru')
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> # plt.ylabel('hits')
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> # plt.legend()
#       <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> # plt.show()
#      <a href='vscode-notebook-cell:/Users/yifan/Desktop/Codes/vscode/2023OS-contest-group2/print.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> lru
#
# File ~/Desktop/Codes/vscode/2023OS-contest-group2/readData.py:11, in read_hit_rates(file_path, name)
#       9 line = lines[i].strip()
#      10 if line.startswith(name):
# ---> 11     hit_rate_line = lines[i + 1].strip().split('\t')
#      12     hit_rates.append(float(hit_rate_line[-1]))
#      13 i += 1
#
# IndexError: list index out of range

# %%
x = [100,110,120,130]
das = [15354,15747,16138,16620]
das_m = [15335,15742,16166,16653]
lru = [15335,15742,16166,16658]
da = [a - b for a, b in zip(das, lru)]
my = [a - b for a, b in zip(das_m, lru)]
plt.plot(x, da, label='das-lru')
plt.plot(x, my, label='my_model-lru')
plt.ylabel('hits')
plt.legend()
plt.show()
