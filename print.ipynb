# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = [300,400,500,600]
das = [40542,40547,40570,41301]
das_m = [40542,40548,40570,41301]
lru = [40542,40544,40546,41301]
plt.plot(x, das, label='das')
plt.plot(x, lru, label='lru')
plt.plot(x, das_m, label='my_model')
plt.ylabel('hits')
plt.legend()
plt.show()

# %%
x = [100,110,120,130,140,150]
das = [15354,]
das_m = [40542,40548,40570,41301]
lru = [40542,40544,40546,41301]
plt.plot(x, das, label='das')
plt.plot(x, lru, label='lru')
plt.plot(x, das_m, label='my_model')
plt.ylabel('hits')
plt.legend()
plt.show()
